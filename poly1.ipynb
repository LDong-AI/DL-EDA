# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 读入训练数据

# %%
train=np.loadtxt('click.csv',delimiter=',',skiprows=1)

# %% [markdown]
# 函数loadtxt用于从文本加载数据;
# delimiter分隔符格;这里的skiprows是指跳过前1行, 如果设置skiprows=2, 就会跳过前两行

# %% [markdown]
# Python中提供了list容器，可以当作数组使用。但列表中的元素可以是任何对象，因此列表中保存的是对象的指针，这样一来，为了保存一个简单的列表[1,2,3]。就需要三个指针和三个整数对象。对于数值运算来说，这种结构显然不够高效。
# Python虽然也提供了array模块，但其只支持一维数组，不支持多维数组，也没有各种运算函数。因而不适合数值运算。

# %%
train_x = train[:,0];
train_y = train[:,1];

# %%
plt.plot(train_x,train_y,'o')

# %% [markdown]
# # 1. 用一次函数拟合

# %% [markdown]
# #参数初始化

# %%
theta0=np.random.rand()
theta1=np.random.rand()

# %% [markdown]
# #预测函数

# %%
def f(x):
    return theta0+theta1*x

# %% [markdown]
# #目标函数

# %%
def E(x,y):
    return 0.5*np.sum((y-f(x))**2)

# %% [markdown]
# #数据标准化
# z=(x-mu)/sigma      sigma ：标准差

# %%
mu=train_x.mean()
sigma=train_x.std()

# %%
def standardize(x):
    return (x-mu)/sigma

# %%
train_z=standardize(train_x)

# %% [markdown]
# #学习率

# %%
ETA = 1e-3

# %%
#误差的差值
diff=1

#更新次数
count=0

# %%
# 直到误差的差值小于0.01为止，重复参数更新
error = E(train_z,train_y)
while diff>1e-2:
    tmp_theta0 = theta0 - ETA * np.sum((f(train_z)-train_y))
    tmp_theta1 = theta1 - ETA * np.sum((f(train_z)-train_y)*train_z)
    
    # 更新参数
    theta0 = tmp_theta0
    theta1 = tmp_theta1
    
    # 计算与上一次误差的差值
    current_error = E(train_z,train_y)
    diff  = error - current_error
    error = current_error
    
    # 输出日志
    count += 1
    log = '第{}次：theta0 = {:.3f}, theta1 = {:.3f}, 差值={: .4f}'
    print(log.format(count,theta0,theta1,diff))
# Out:
# 第1次：theta0 = 8.676, theta1 = 2.586, 差值= 76305.5628
# 第2次：theta0 = 17.085, theta1 = 4.404, 差值= 73283.8625
# 第3次：theta0 = 25.326, theta1 = 6.185, 差值= 70381.8216
# 第4次：theta0 = 33.403, theta1 = 7.931, 差值= 67594.7014
# 第5次：theta0 = 41.318, theta1 = 9.642, 差值= 64917.9512
# 第6次：theta0 = 49.074, theta1 = 11.319, 差值= 62347.2004
# 第7次：theta0 = 56.676, theta1 = 12.962, 差值= 59878.2512
# 第8次：theta0 = 64.125, theta1 = 14.573, 差值= 57507.0725
# 第9次：theta0 = 71.426, theta1 = 16.151, 差值= 55229.7924
# 第10次：theta0 = 78.580, theta1 = 17.697, 差值= 53042.6926
# 第11次：theta0 = 85.592, theta1 = 19.213, 差值= 50942.2020
# 第12次：theta0 = 92.463, theta1 = 20.698, 差值= 48924.8908
# 第13次：theta0 = 99.197, theta1 = 22.154, 差值= 46987.4651
# 第14次：theta0 = 105.796, theta1 = 23.580, 差值= 45126.7615
# 第15次：theta0 = 112.263, theta1 = 24.978, 差值= 43339.7418
# 第16次：theta0 = 118.601, theta1 = 26.348, 差值= 41623.4880
# 第17次：theta0 = 124.812, theta1 = 27.691, 差值= 39975.1979
# 第18次：theta0 = 130.898, theta1 = 29.007, 差值= 38392.1800
# 第19次：theta0 = 136.863, theta1 = 30.296, 差值= 36871.8497
# 第20次：theta0 = 142.709, theta1 = 31.560, 差值= 35411.7244
# 第21次：theta0 = 148.438, theta1 = 32.798, 差值= 34009.4202
# 第22次：theta0 = 154.052, theta1 = 34.012, 差值= 32662.6471
# 第23次：theta0 = 159.554, theta1 = 35.201, 差值= 31369.2063
# 第24次：theta0 = 164.946, theta1 = 36.367, 差值= 30126.9857
# 第25次：theta0 = 170.230, theta1 = 37.509, 差值= 28933.9571
# 第26次：theta0 = 175.408, theta1 = 38.628, 差值= 27788.1724
# 第27次：theta0 = 180.483, theta1 = 39.725, 差值= 26687.7608
# 第28次：theta0 = 185.457, theta1 = 40.800, 差值= 25630.9254
# 第29次：theta0 = 190.331, theta1 = 41.854, 差值= 24615.9408
# 第30次：theta0 = 195.107, theta1 = 42.886, 差值= 23641.1495
# 第31次：theta0 = 199.788, theta1 = 43.898, 差值= 22704.9600
# 第32次：theta0 = 204.375, theta1 = 44.890, 差值= 21805.8436
# 第33次：theta0 = 208.871, theta1 = 45.862, 差值= 20942.3322
# 第34次：theta0 = 213.276, theta1 = 46.814, 差值= 20113.0158
# 第35次：theta0 = 217.594, theta1 = 47.747, 差值= 19316.5404
# 第36次：theta0 = 221.825, theta1 = 48.662, 差值= 18551.6054
# 第37次：theta0 = 225.971, theta1 = 49.558, 差值= 17816.9618
# 第38次：theta0 = 230.035, theta1 = 50.437, 差值= 17111.4101
# 第39次：theta0 = 234.017, theta1 = 51.297, 差值= 16433.7983
# 第40次：theta0 = 237.920, theta1 = 52.141, 差值= 15783.0199
# 第41次：theta0 = 241.744, theta1 = 52.968, 差值= 15158.0123
# 第42次：theta0 = 245.492, theta1 = 53.778, 差值= 14557.7550
# 第43次：theta0 = 249.166, theta1 = 54.572, 差值= 13981.2679
# 第44次：theta0 = 252.765, theta1 = 55.350, 差值= 13427.6097
# 第45次：theta0 = 256.293, theta1 = 56.113, 差值= 12895.8764
# 第46次：theta0 = 259.750, theta1 = 56.860, 差值= 12385.1997
# 第47次：theta0 = 263.138, theta1 = 57.593, 差值= 11894.7458
# 第48次：theta0 = 266.458, theta1 = 58.310, 差值= 11423.7138
# 第49次：theta0 = 269.712, theta1 = 59.014, 差值= 10971.3348
# 第50次：theta0 = 272.901, theta1 = 59.703, 差值= 10536.8699
# 第51次：theta0 = 276.026, theta1 = 60.378, 差值= 10119.6099
# 第52次：theta0 = 279.088, theta1 = 61.040, 差值= 9718.8733
# 第53次：theta0 = 282.090, theta1 = 61.689, 差值= 9334.0059
# 第54次：theta0 = 285.031, theta1 = 62.325, 差值= 8964.3793
# 第55次：theta0 = 287.913, theta1 = 62.948, 差值= 8609.3899
# 第56次：theta0 = 290.738, theta1 = 63.559, 差值= 8268.4580
# 第57次：theta0 = 293.506, theta1 = 64.157, 差值= 7941.0271
# 第58次：theta0 = 296.219, theta1 = 64.744, 差值= 7626.5624
# 第59次：theta0 = 298.878, theta1 = 65.318, 差值= 7324.5505
# 第60次：theta0 = 301.483, theta1 = 65.881, 差值= 7034.4983
# 第61次：theta0 = 304.036, theta1 = 66.433, 差值= 6755.9322
# 第62次：theta0 = 306.539, theta1 = 66.974, 差值= 6488.3973
# 第63次：theta0 = 308.991, theta1 = 67.504, 差值= 6231.4568
# 第64次：theta0 = 311.394, theta1 = 68.024, 差值= 5984.6911
# 第65次：theta0 = 313.749, theta1 = 68.533, 差值= 5747.6973
# 第66次：theta0 = 316.057, theta1 = 69.032, 差值= 5520.0885
# 第67次：theta0 = 318.319, theta1 = 69.521, 差值= 5301.4930
# 第68次：theta0 = 320.536, theta1 = 70.000, 差值= 5091.5539
# 第69次：theta0 = 322.708, theta1 = 70.470, 差值= 4889.9283
# 第70次：theta0 = 324.837, theta1 = 70.930, 差值= 4696.2872
# 第71次：theta0 = 326.923, theta1 = 71.381, 差值= 4510.3142
# 第72次：theta0 = 328.968, theta1 = 71.823, 差值= 4331.7058
# 第73次：theta0 = 330.971, theta1 = 72.256, 差值= 4160.1702
# 第74次：theta0 = 332.935, theta1 = 72.680, 差值= 3995.4275
# 第75次：theta0 = 334.859, theta1 = 73.096, 差值= 3837.2085
# 第76次：theta0 = 336.745, theta1 = 73.504, 差值= 3685.2551
# 第77次：theta0 = 338.593, theta1 = 73.903, 差值= 3539.3190
# 第78次：theta0 = 340.404, theta1 = 74.295, 差值= 3399.1619
# 第79次：theta0 = 342.179, theta1 = 74.679, 差值= 3264.5551
# 第80次：theta0 = 343.919, theta1 = 75.055, 差值= 3135.2788
# 第81次：theta0 = 345.623, theta1 = 75.423, 差值= 3011.1217
# 第82次：theta0 = 347.294, theta1 = 75.784, 差值= 2891.8813
# 第83次：theta0 = 348.931, theta1 = 76.138, 差值= 2777.3628
# 第84次：theta0 = 350.535, theta1 = 76.485, 差值= 2667.3792
# 第85次：theta0 = 352.108, theta1 = 76.825, 差值= 2561.7510
# 第86次：theta0 = 353.648, theta1 = 77.158, 差值= 2460.3057
# 第87次：theta0 = 355.158, theta1 = 77.484, 差值= 2362.8776
# 第88次：theta0 = 356.638, theta1 = 77.804, 差值= 2269.3076
# 第89次：theta0 = 358.089, theta1 = 78.118, 差值= 2179.4430
# 第90次：theta0 = 359.510, theta1 = 78.425, 差值= 2093.1371
# 第91次：theta0 = 360.903, theta1 = 78.726, 差值= 2010.2489
# 第92次：theta0 = 362.267, theta1 = 79.021, 差值= 1930.6430
# 第93次：theta0 = 363.605, theta1 = 79.310, 差值= 1854.1895
# 第94次：theta0 = 364.916, theta1 = 79.594, 差值= 1780.7636
# 第95次：theta0 = 366.201, theta1 = 79.871, 差值= 1710.2454
# 第96次：theta0 = 367.460, theta1 = 80.143, 差值= 1642.5197
# 第97次：theta0 = 368.694, theta1 = 80.410, 差值= 1577.4759
# 第98次：theta0 = 369.903, theta1 = 80.671, 差值= 1515.0079
# 第99次：theta0 = 371.088, theta1 = 80.928, 差值= 1455.0135
# 第100次：theta0 = 372.249, theta1 = 81.179, 差值= 1397.3950
# 第101次：theta0 = 373.387, theta1 = 81.425, 差值= 1342.0582
# 第102次：theta0 = 374.502, theta1 = 81.666, 差值= 1288.9127
# 第103次：theta0 = 375.595, theta1 = 81.902, 差值= 1237.8717
# 第104次：theta0 = 376.666, theta1 = 82.134, 差值= 1188.8520
# 第105次：theta0 = 377.716, theta1 = 82.360, 差值= 1141.7735
# 第106次：theta0 = 378.745, theta1 = 82.583, 差值= 1096.5592
# 第107次：theta0 = 379.753, theta1 = 82.801, 差值= 1053.1355
# 第108次：theta0 = 380.741, theta1 = 83.014, 差值= 1011.4313
# 第109次：theta0 = 381.709, theta1 = 83.224, 差值= 971.3786
# 第110次：theta0 = 382.658, theta1 = 83.429, 差值= 932.9120
# 第111次：theta0 = 383.587, theta1 = 83.630, 差值= 895.9687
# 第112次：theta0 = 384.499, theta1 = 83.827, 差值= 860.4884
# 第113次：theta0 = 385.392, theta1 = 84.020, 差值= 826.4130
# 第114次：theta0 = 386.267, theta1 = 84.209, 差值= 793.6871
# 第115次：theta0 = 387.125, theta1 = 84.394, 差值= 762.2571
# 第116次：theta0 = 387.965, theta1 = 84.576, 差值= 732.0717
# 第117次：theta0 = 388.789, theta1 = 84.754, 差值= 703.0816
# 第118次：theta0 = 389.596, theta1 = 84.929, 差值= 675.2396
# 第119次：theta0 = 390.387, theta1 = 85.100, 差值= 648.5001
# 第120次：theta0 = 391.162, theta1 = 85.267, 差值= 622.8195
# 第121次：theta0 = 391.922, theta1 = 85.431, 差值= 598.1559
# 第122次：theta0 = 392.667, theta1 = 85.592, 差值= 574.4689
# 第123次：theta0 = 393.396, theta1 = 85.750, 差值= 551.7199
# 第124次：theta0 = 394.111, theta1 = 85.905, 差值= 529.8718
# 第125次：theta0 = 394.812, theta1 = 86.056, 差值= 508.8889
# 第126次：theta0 = 395.499, theta1 = 86.205, 差值= 488.7369
# 第127次：theta0 = 396.172, theta1 = 86.350, 差值= 469.3829
# 第128次：theta0 = 396.831, theta1 = 86.493, 差值= 450.7953
# 第129次：theta0 = 397.478, theta1 = 86.632, 差值= 432.9439
# 第130次：theta0 = 398.111, theta1 = 86.769, 差值= 415.7993
# 第131次：theta0 = 398.732, theta1 = 86.903, 差值= 399.3336
# 第132次：theta0 = 399.340, theta1 = 87.035, 差值= 383.5200
# 第133次：theta0 = 399.937, theta1 = 87.164, 差值= 368.3326
# 第134次：theta0 = 400.521, theta1 = 87.290, 差值= 353.7466
# 第135次：theta0 = 401.093, theta1 = 87.414, 差值= 339.7383
# 第136次：theta0 = 401.655, theta1 = 87.535, 差值= 326.2846
# 第137次：theta0 = 402.205, theta1 = 87.654, 差值= 313.3638
# 第138次：theta0 = 402.743, theta1 = 87.771, 差值= 300.9546
# 第139次：theta0 = 403.272, theta1 = 87.885, 差值= 289.0368
# 第140次：theta0 = 403.789, theta1 = 87.997, 差值= 277.5909
# 第141次：theta0 = 404.296, theta1 = 88.106, 差值= 266.5983
# 第142次：theta0 = 404.793, theta1 = 88.214, 差值= 256.0410
# 第143次：theta0 = 405.281, theta1 = 88.319, 差值= 245.9018
# 第144次：theta0 = 405.758, theta1 = 88.422, 差值= 236.1641
# 第145次：theta0 = 406.226, theta1 = 88.523, 差值= 226.8120
# 第146次：theta0 = 406.684, theta1 = 88.622, 差值= 217.8302
# 第147次：theta0 = 407.134, theta1 = 88.720, 差值= 209.2042
# 第148次：theta0 = 407.574, theta1 = 88.815, 差值= 200.9197
# 第149次：theta0 = 408.005, theta1 = 88.908, 差值= 192.9632
# 第150次：theta0 = 408.428, theta1 = 88.999, 差值= 185.3219
# 第151次：theta0 = 408.843, theta1 = 89.089, 差值= 177.9832
# 第152次：theta0 = 409.249, theta1 = 89.177, 差值= 170.9350
# 第153次：theta0 = 409.647, theta1 = 89.263, 差值= 164.1660
# 第154次：theta0 = 410.037, theta1 = 89.347, 差值= 157.6650
# 第155次：theta0 = 410.419, theta1 = 89.430, 差值= 151.4215
# 第156次：theta0 = 410.794, theta1 = 89.511, 差值= 145.4252
# 第157次：theta0 = 411.161, theta1 = 89.590, 差值= 139.6664
# 第158次：theta0 = 411.521, theta1 = 89.668, 差值= 134.1356
# 第159次：theta0 = 411.873, theta1 = 89.744, 差值= 128.8238
# 第160次：theta0 = 412.219, theta1 = 89.819, 差值= 123.7224
# 第161次：theta0 = 412.558, theta1 = 89.892, 差值= 118.8230
# 第162次：theta0 = 412.889, theta1 = 89.964, 差值= 114.1176
# 第163次：theta0 = 413.215, theta1 = 90.034, 差值= 109.5985
# 第164次：theta0 = 413.533, theta1 = 90.103, 差值= 105.2584
# 第165次：theta0 = 413.846, theta1 = 90.170, 差值= 101.0902
# 第166次：theta0 = 414.152, theta1 = 90.237, 差值= 97.0870
# 第167次：theta0 = 414.452, theta1 = 90.301, 差值= 93.2424
# 第168次：theta0 = 414.746, theta1 = 90.365, 差值= 89.5500
# 第169次：theta0 = 415.034, theta1 = 90.427, 差值= 86.0038
# 第170次：theta0 = 415.316, theta1 = 90.488, 差值= 82.5980
# 第171次：theta0 = 415.593, theta1 = 90.548, 差值= 79.3272
# 第172次：theta0 = 415.864, theta1 = 90.607, 差值= 76.1858
# 第173次：theta0 = 416.130, theta1 = 90.664, 差值= 73.1689
# 第174次：theta0 = 416.390, theta1 = 90.720, 差值= 70.2714
# 第175次：theta0 = 416.645, theta1 = 90.776, 差值= 67.4886
# 第176次：theta0 = 416.895, theta1 = 90.830, 差值= 64.8161
# 第177次：theta0 = 417.140, theta1 = 90.883, 差值= 62.2494
# 第178次：theta0 = 417.381, theta1 = 90.935, 差值= 59.7843
# 第179次：theta0 = 417.616, theta1 = 90.985, 差值= 57.4168
# 第180次：theta0 = 417.847, theta1 = 91.035, 差值= 55.1431
# 第181次：theta0 = 418.073, theta1 = 91.084, 差值= 52.9594
# 第182次：theta0 = 418.294, theta1 = 91.132, 差值= 50.8623
# 第183次：theta0 = 418.511, theta1 = 91.179, 差值= 48.8481
# 第184次：theta0 = 418.724, theta1 = 91.225, 差值= 46.9137
# 第185次：theta0 = 418.933, theta1 = 91.270, 差值= 45.0559
# 第186次：theta0 = 419.137, theta1 = 91.314, 差值= 43.2717
# 第187次：theta0 = 419.337, theta1 = 91.358, 差值= 41.5582
# 第188次：theta0 = 419.534, theta1 = 91.400, 差值= 39.9125
# 第189次：theta0 = 419.726, theta1 = 91.442, 差值= 38.3319
# 第190次：theta0 = 419.914, theta1 = 91.482, 差值= 36.8140
# 第191次：theta0 = 420.099, theta1 = 91.522, 差值= 35.3561
# 第192次：theta0 = 420.280, theta1 = 91.561, 差值= 33.9560
# 第193次：theta0 = 420.457, theta1 = 91.600, 差值= 32.6114
# 第194次：theta0 = 420.631, theta1 = 91.637, 差值= 31.3200
# 第195次：theta0 = 420.802, theta1 = 91.674, 差值= 30.0797
# 第196次：theta0 = 420.969, theta1 = 91.710, 差值= 28.8885
# 第197次：theta0 = 421.132, theta1 = 91.746, 差值= 27.7446
# 第198次：theta0 = 421.293, theta1 = 91.780, 差值= 26.6459
# 第199次：theta0 = 421.450, theta1 = 91.814, 差值= 25.5907
# 第200次：theta0 = 421.604, theta1 = 91.848, 差值= 24.5773
# 第201次：theta0 = 421.755, theta1 = 91.880, 差值= 23.6040
# 第202次：theta0 = 421.903, theta1 = 91.912, 差值= 22.6693
# 第203次：theta0 = 422.048, theta1 = 91.943, 差值= 21.7716
# 第204次：theta0 = 422.190, theta1 = 91.974, 差值= 20.9095
# 第205次：theta0 = 422.329, theta1 = 92.004, 差值= 20.0815
# 第206次：theta0 = 422.465, theta1 = 92.034, 差值= 19.2862
# 第207次：theta0 = 422.599, theta1 = 92.063, 差值= 18.5225
# 第208次：theta0 = 422.730, theta1 = 92.091, 差值= 17.7890
# 第209次：theta0 = 422.858, theta1 = 92.119, 差值= 17.0846
# 第210次：theta0 = 422.984, theta1 = 92.146, 差值= 16.4080
# 第211次：theta0 = 423.108, theta1 = 92.173, 差值= 15.7583
# 第212次：theta0 = 423.228, theta1 = 92.199, 差值= 15.1342
# 第213次：theta0 = 423.347, theta1 = 92.224, 差值= 14.5349
# 第214次：theta0 = 423.463, theta1 = 92.249, 差值= 13.9593
# 第215次：theta0 = 423.577, theta1 = 92.274, 差值= 13.4065
# 第216次：theta0 = 423.688, theta1 = 92.298, 差值= 12.8756
# 第217次：theta0 = 423.797, theta1 = 92.322, 差值= 12.3658
# 第218次：theta0 = 423.904, theta1 = 92.345, 差值= 11.8761
# 第219次：theta0 = 424.009, theta1 = 92.368, 差值= 11.4058
# 第220次：theta0 = 424.112, theta1 = 92.390, 差值= 10.9541
# 第221次：theta0 = 424.213, theta1 = 92.412, 差值= 10.5203
# 第222次：theta0 = 424.312, theta1 = 92.433, 差值= 10.1037
# 第223次：theta0 = 424.408, theta1 = 92.454, 差值= 9.7036
# 第224次：theta0 = 424.503, theta1 = 92.474, 差值= 9.3194
# 第225次：theta0 = 424.596, theta1 = 92.494, 差值= 8.9503
# 第226次：theta0 = 424.687, theta1 = 92.514, 差值= 8.5959
# 第227次：theta0 = 424.776, theta1 = 92.533, 差值= 8.2555
# 第228次：theta0 = 424.864, theta1 = 92.552, 差值= 7.9286
# 第229次：theta0 = 424.950, theta1 = 92.571, 差值= 7.6146
# 第230次：theta0 = 425.034, theta1 = 92.589, 差值= 7.3131
# 第231次：theta0 = 425.116, theta1 = 92.607, 差值= 7.0235
# 第232次：theta0 = 425.197, theta1 = 92.624, 差值= 6.7453
# 第233次：theta0 = 425.276, theta1 = 92.641, 差值= 6.4782
# 第234次：theta0 = 425.353, theta1 = 92.658, 差值= 6.2217
# 第235次：theta0 = 425.429, theta1 = 92.674, 差值= 5.9753
# 第236次：theta0 = 425.504, theta1 = 92.691, 差值= 5.7387
# 第237次：theta0 = 425.577, theta1 = 92.706, 差值= 5.5114
# 第238次：theta0 = 425.648, theta1 = 92.722, 差值= 5.2932
# 第239次：theta0 = 425.718, theta1 = 92.737, 差值= 5.0836
# 第240次：theta0 = 425.787, theta1 = 92.752, 差值= 4.8823
# 第241次：theta0 = 425.854, theta1 = 92.766, 差值= 4.6889
# 第242次：theta0 = 425.920, theta1 = 92.781, 差值= 4.5032
# 第243次：theta0 = 425.984, theta1 = 92.794, 差值= 4.3249
# 第244次：theta0 = 426.048, theta1 = 92.808, 差值= 4.1536
# 第245次：theta0 = 426.110, theta1 = 92.822, 差值= 3.9892
# 第246次：theta0 = 426.171, theta1 = 92.835, 差值= 3.8312
# 第247次：theta0 = 426.230, theta1 = 92.848, 差值= 3.6795
# 第248次：theta0 = 426.289, theta1 = 92.860, 差值= 3.5338
# 第249次：theta0 = 426.346, theta1 = 92.873, 差值= 3.3938
# 第250次：theta0 = 426.402, theta1 = 92.885, 差值= 3.2594
# 第251次：theta0 = 426.457, theta1 = 92.897, 差值= 3.1304
# 第252次：theta0 = 426.511, theta1 = 92.908, 差值= 3.0064
# 第253次：theta0 = 426.564, theta1 = 92.920, 差值= 2.8873
# 第254次：theta0 = 426.615, theta1 = 92.931, 差值= 2.7730
# 第255次：theta0 = 426.666, theta1 = 92.942, 差值= 2.6632
# 第256次：theta0 = 426.716, theta1 = 92.953, 差值= 2.5577
# 第257次：theta0 = 426.764, theta1 = 92.963, 差值= 2.4564
# 第258次：theta0 = 426.812, theta1 = 92.973, 差值= 2.3592
# 第259次：theta0 = 426.859, theta1 = 92.983, 差值= 2.2657
# 第260次：theta0 = 426.905, theta1 = 92.993, 差值= 2.1760
# 第261次：theta0 = 426.950, theta1 = 93.003, 差值= 2.0899
# 第262次：theta0 = 426.994, theta1 = 93.013, 差值= 2.0071
# 第263次：theta0 = 427.037, theta1 = 93.022, 差值= 1.9276
# 第264次：theta0 = 427.079, theta1 = 93.031, 差值= 1.8513
# 第265次：theta0 = 427.120, theta1 = 93.040, 差值= 1.7780
# 第266次：theta0 = 427.161, theta1 = 93.049, 差值= 1.7076
# 第267次：theta0 = 427.201, theta1 = 93.057, 差值= 1.6399
# 第268次：theta0 = 427.240, theta1 = 93.066, 差值= 1.5750
# 第269次：theta0 = 427.278, theta1 = 93.074, 差值= 1.5126
# 第270次：theta0 = 427.315, theta1 = 93.082, 差值= 1.4527
# 第271次：theta0 = 427.352, theta1 = 93.090, 差值= 1.3952
# 第272次：theta0 = 427.388, theta1 = 93.098, 差值= 1.3400
# 第273次：theta0 = 427.423, theta1 = 93.105, 差值= 1.2869
# 第274次：theta0 = 427.458, theta1 = 93.113, 差值= 1.2359
# 第275次：theta0 = 427.492, theta1 = 93.120, 差值= 1.1870
# 第276次：theta0 = 427.525, theta1 = 93.127, 差值= 1.1400
# 第277次：theta0 = 427.557, theta1 = 93.134, 差值= 1.0948
# 第278次：theta0 = 427.589, theta1 = 93.141, 差值= 1.0515
# 第279次：theta0 = 427.620, theta1 = 93.148, 差值= 1.0098
# 第280次：theta0 = 427.651, theta1 = 93.155, 差值= 0.9699
# 第281次：theta0 = 427.681, theta1 = 93.161, 差值= 0.9314
# 第282次：theta0 = 427.710, theta1 = 93.168, 差值= 0.8946
# 第283次：theta0 = 427.739, theta1 = 93.174, 差值= 0.8591
# 第284次：theta0 = 427.767, theta1 = 93.180, 差值= 0.8251
# 第285次：theta0 = 427.795, theta1 = 93.186, 差值= 0.7924
# 第286次：theta0 = 427.822, theta1 = 93.192, 差值= 0.7611
# 第287次：theta0 = 427.849, theta1 = 93.197, 差值= 0.7309
# 第288次：theta0 = 427.875, theta1 = 93.203, 差值= 0.7020
# 第289次：theta0 = 427.900, theta1 = 93.209, 差值= 0.6742
# 第290次：theta0 = 427.925, theta1 = 93.214, 差值= 0.6475
# 第291次：theta0 = 427.950, theta1 = 93.219, 差值= 0.6218
# 第292次：theta0 = 427.974, theta1 = 93.224, 差值= 0.5972
# 第293次：theta0 = 427.997, theta1 = 93.230, 差值= 0.5736
# 第294次：theta0 = 428.020, theta1 = 93.235, 差值= 0.5509
# 第295次：theta0 = 428.043, theta1 = 93.239, 差值= 0.5290
# 第296次：theta0 = 428.065, theta1 = 93.244, 差值= 0.5081
# 第297次：theta0 = 428.087, theta1 = 93.249, 差值= 0.4880
# 第298次：theta0 = 428.108, theta1 = 93.254, 差值= 0.4686
# 第299次：theta0 = 428.129, theta1 = 93.258, 差值= 0.4501
# 第300次：theta0 = 428.149, theta1 = 93.262, 差值= 0.4323
# 第301次：theta0 = 428.169, theta1 = 93.267, 差值= 0.4151
# 第302次：theta0 = 428.189, theta1 = 93.271, 差值= 0.3987
# 第303次：theta0 = 428.208, theta1 = 93.275, 差值= 0.3829
# 第304次：theta0 = 428.227, theta1 = 93.279, 差值= 0.3678
# 第305次：theta0 = 428.245, theta1 = 93.283, 差值= 0.3532
# 第306次：theta0 = 428.263, theta1 = 93.287, 差值= 0.3392
# 第307次：theta0 = 428.281, theta1 = 93.291, 差值= 0.3258
# 第308次：theta0 = 428.299, theta1 = 93.295, 差值= 0.3129
# 第309次：theta0 = 428.316, theta1 = 93.298, 差值= 0.3005
# 第310次：theta0 = 428.332, theta1 = 93.302, 差值= 0.2886
# 第311次：theta0 = 428.349, theta1 = 93.306, 差值= 0.2772
# 第312次：theta0 = 428.365, theta1 = 93.309, 差值= 0.2662
# 第313次：theta0 = 428.380, theta1 = 93.312, 差值= 0.2556
# 第314次：theta0 = 428.396, theta1 = 93.316, 差值= 0.2455
# 第315次：theta0 = 428.411, theta1 = 93.319, 差值= 0.2358
# 第316次：theta0 = 428.426, theta1 = 93.322, 差值= 0.2265
# 第317次：theta0 = 428.440, theta1 = 93.325, 差值= 0.2175
# 第318次：theta0 = 428.454, theta1 = 93.328, 差值= 0.2089
# 第319次：theta0 = 428.468, theta1 = 93.331, 差值= 0.2006
# 第320次：theta0 = 428.482, theta1 = 93.334, 差值= 0.1927
# 第321次：theta0 = 428.495, theta1 = 93.337, 差值= 0.1850
# 第322次：theta0 = 428.508, theta1 = 93.340, 差值= 0.1777
# 第323次：theta0 = 428.521, theta1 = 93.343, 差值= 0.1707
# 第324次：theta0 = 428.534, theta1 = 93.346, 差值= 0.1639
# 第325次：theta0 = 428.546, theta1 = 93.348, 差值= 0.1574
# 第326次：theta0 = 428.558, theta1 = 93.351, 差值= 0.1512
# 第327次：theta0 = 428.570, theta1 = 93.353, 差值= 0.1452
# 第328次：theta0 = 428.582, theta1 = 93.356, 差值= 0.1394
# 第329次：theta0 = 428.593, theta1 = 93.358, 差值= 0.1339
# 第330次：theta0 = 428.604, theta1 = 93.361, 差值= 0.1286
# 第331次：theta0 = 428.615, theta1 = 93.363, 差值= 0.1235
# 第332次：theta0 = 428.626, theta1 = 93.365, 差值= 0.1186
# 第333次：theta0 = 428.636, theta1 = 93.368, 差值= 0.1139
# 第334次：theta0 = 428.646, theta1 = 93.370, 差值= 0.1094
# 第335次：theta0 = 428.657, theta1 = 93.372, 差值= 0.1051
# 第336次：theta0 = 428.666, theta1 = 93.374, 差值= 0.1009
# 第337次：theta0 = 428.676, theta1 = 93.376, 差值= 0.0969
# 第338次：theta0 = 428.686, theta1 = 93.378, 差值= 0.0931
# 第339次：theta0 = 428.695, theta1 = 93.380, 差值= 0.0894
# 第340次：theta0 = 428.704, theta1 = 93.382, 差值= 0.0859
# 第341次：theta0 = 428.713, theta1 = 93.384, 差值= 0.0825
# 第342次：theta0 = 428.722, theta1 = 93.386, 差值= 0.0792
# 第343次：theta0 = 428.730, theta1 = 93.388, 差值= 0.0761
# 第344次：theta0 = 428.739, theta1 = 93.390, 差值= 0.0731
# 第345次：theta0 = 428.747, theta1 = 93.392, 差值= 0.0702
# 第346次：theta0 = 428.755, theta1 = 93.393, 差值= 0.0674
# 第347次：theta0 = 428.763, theta1 = 93.395, 差值= 0.0647
# 第348次：theta0 = 428.771, theta1 = 93.397, 差值= 0.0622
# 第349次：theta0 = 428.778, theta1 = 93.398, 差值= 0.0597
# 第350次：theta0 = 428.786, theta1 = 93.400, 差值= 0.0573
# 第351次：theta0 = 428.793, theta1 = 93.402, 差值= 0.0551
# 第352次：theta0 = 428.800, theta1 = 93.403, 差值= 0.0529
# 第353次：theta0 = 428.807, theta1 = 93.405, 差值= 0.0508
# 第354次：theta0 = 428.814, theta1 = 93.406, 差值= 0.0488
# 第355次：theta0 = 428.821, theta1 = 93.408, 差值= 0.0468
# 第356次：theta0 = 428.827, theta1 = 93.409, 差值= 0.0450
# 第357次：theta0 = 428.834, theta1 = 93.410, 差值= 0.0432
# 第358次：theta0 = 428.840, theta1 = 93.412, 差值= 0.0415
# 第359次：theta0 = 428.846, theta1 = 93.413, 差值= 0.0398
# 第360次：theta0 = 428.852, theta1 = 93.414, 差值= 0.0383
# 第361次：theta0 = 428.858, theta1 = 93.416, 差值= 0.0368
# 第362次：theta0 = 428.864, theta1 = 93.417, 差值= 0.0353
# 第363次：theta0 = 428.870, theta1 = 93.418, 差值= 0.0339
# 第364次：theta0 = 428.875, theta1 = 93.419, 差值= 0.0326
# 第365次：theta0 = 428.881, theta1 = 93.421, 差值= 0.0313
# 第366次：theta0 = 428.886, theta1 = 93.422, 差值= 0.0300
# 第367次：theta0 = 428.891, theta1 = 93.423, 差值= 0.0288
# 第368次：theta0 = 428.897, theta1 = 93.424, 差值= 0.0277
# 第369次：theta0 = 428.902, theta1 = 93.425, 差值= 0.0266
# 第370次：theta0 = 428.907, theta1 = 93.426, 差值= 0.0256
# 第371次：theta0 = 428.912, theta1 = 93.427, 差值= 0.0245
# 第372次：theta0 = 428.916, theta1 = 93.428, 差值= 0.0236
# 第373次：theta0 = 428.921, theta1 = 93.429, 差值= 0.0226
# 第374次：theta0 = 428.926, theta1 = 93.430, 差值= 0.0217
# 第375次：theta0 = 428.930, theta1 = 93.431, 差值= 0.0209
# 第376次：theta0 = 428.934, theta1 = 93.432, 差值= 0.0200
# 第377次：theta0 = 428.939, theta1 = 93.433, 差值= 0.0193
# 第378次：theta0 = 428.943, theta1 = 93.434, 差值= 0.0185
# 第379次：theta0 = 428.947, theta1 = 93.435, 差值= 0.0178
# 第380次：theta0 = 428.951, theta1 = 93.436, 差值= 0.0171
# 第381次：theta0 = 428.955, theta1 = 93.437, 差值= 0.0164
# 第382次：theta0 = 428.959, theta1 = 93.437, 差值= 0.0157
# 第383次：theta0 = 428.963, theta1 = 93.438, 差值= 0.0151
# 第384次：theta0 = 428.967, theta1 = 93.439, 差值= 0.0145
# 第385次：theta0 = 428.970, theta1 = 93.440, 差值= 0.0139
# 第386次：theta0 = 428.974, theta1 = 93.441, 差值= 0.0134
# 第387次：theta0 = 428.977, theta1 = 93.441, 差值= 0.0129
# 第388次：theta0 = 428.981, theta1 = 93.442, 差值= 0.0123
# 第389次：theta0 = 428.984, theta1 = 93.443, 差值= 0.0119
# 第390次：theta0 = 428.988, theta1 = 93.444, 差值= 0.0114
# 第391次：theta0 = 428.991, theta1 = 93.444, 差值= 0.0109
# 第392次：theta0 = 428.994, theta1 = 93.445, 差值= 0.0105
# 第393次：theta0 = 428.997, theta1 = 93.446, 差值= 0.0101
# 第394次：theta0 = 429.000, theta1 = 93.446, 差值= 0.0097

# %% [markdown]
# # 绘图确认

# %%
x = np.linspace(-3,3,100)
plt.plot(train_z,train_y,'o')
plt.plot(x,f(x))
plt.show()
